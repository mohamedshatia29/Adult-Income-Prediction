# %%
import pickle
import pandas as pd

with open('xgboost_model.pkl', 'rb') as model_file:
    loaded_model = pickle.load(model_file)

# %%
input_data = {
    'age': 39,
    'workclass': 'State-gov',
    'education': 'Bachelors',
    'marital_status': 'Single',
    'occupation': 'Adm-clerical',
    'relationship': 'Not-in-family',
    'race': 'White',
    'sex': 'Male',
    'hours_per_week': 40,
    'native_country': 'United-States',
    'net_capital': 'Low'
}

input_df = pd.DataFrame([input_data])

# %%
prediction = loaded_model.predict(input_df)[0]

prediction_dict = {0: '<= 50K', 1: '>= 50K'}
result = prediction_dict[prediction]

print("Prediction:", result)
# Out:
# Prediction: <= 50K

# %%
input_data = {
    'age': 52,
    'workclass': 'Self-emp-inc',
    'education': 'HS-grad',
    'marital_status': 'Married',
    'occupation': 'Exec-managerial',
    'relationship': 'Wife',
    'race': 'White',
    'sex': 'Female',
    'hours_per_week': 40,
    'native_country': 'United-States',
    'net_capital': 'High'
}

input_df = pd.DataFrame([input_data])

# %%
prediction = loaded_model.predict(input_df)[0]

prediction_dict = {0: '<= 50K', 1: '>= 50K'}
result = prediction_dict[prediction]

print("Prediction:", result)
# Out:
# Prediction: >= 50K

# %%
input_data = {
    'age': 37,
    'workclass': 'Private',
    'education': 'Some-college',
    'marital_status': 'Married',
    'occupation': 'Exec-managerial',
    'relationship': 'Husband',
    'race': 'Black',
    'sex': 'Male',
    'hours_per_week': 80,
    'native_country': 'United-States',
    'net_capital': 'Low'
}

input_df = pd.DataFrame([input_data])

# %%
prediction = loaded_model.predict(input_df)[0]

prediction_dict = {0: '<= 50K', 1: '>= 50K'}
result = prediction_dict[prediction]

print("Prediction:", result)
# Out:
# Prediction: >= 50K
